# %%
# Nima Nejatifar

import numpy as np
from matplotlib import pyplot
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics
from sklearn.metrics import r2_score

# %%
# dataset1 :
x1 = np.random.rand(5,1) *10 -5
y1 = 2 * x1 + 5
y1 = y1 + np.random.normal(scale=1, size=y1.shape)
plt.plot(x1, y1, 'bo')

# %%
# DEGREE = 1

poly_features = PolynomialFeatures(degree=1, include_bias=False)
x1_poly = poly_features.fit_transform(x1)
reg1_1 = LinearRegression()
reg1_1.fit(x1_poly, y1)
# Out:
# LinearRegression()

# %%
# x1_vals = np.linspace(-5,5,5).reshape(-1,1)
x1_vals = x1
x1_vals_poly = poly_features.transform(x1_vals)
y1_vals = reg1_1.predict(x1_vals_poly)
plt.suptitle('DATA 1 : Degree 1')
plt.ylabel('Output')
plt.xlabel('Input')
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x1, y1)
plt.plot(x1_vals, y1_vals, color="r")
plt.show()

# %%
len(y1_vals)
# Out:
# 5

# %%
print(f" intercept : {reg1_1.intercept_} \n coefficient : {reg1_1.coef_} \n MSE : {metrics.mean_squared_error(y1, y1_vals)} \n R2 Score : {r2_score(y1, y1_vals)}")
# Out:
#  intercept : [5.21273487]
#  coefficient : [[2.39758323]]
#  MSE : 0.9130683677420119
#  R2 Score : 0.936899123507055

# %%
## DEGREE = 4

poly_features_4 = PolynomialFeatures(degree=4, include_bias=False)
x1_poly_4 = poly_features_4.fit_transform(x1)
reg1_1_4 = LinearRegression()
reg1_1_4.fit(x1_poly_4, y1)
# Out:
# LinearRegression()

# %%
x1_vals_4_show = np.linspace(-5,5,500).reshape(-1,1)
x1_vals_poly_4_show = poly_features_4.transform(x1_vals_4_show)
y1_vals_4_show = reg1_1_4.predict(x1_vals_poly_4_show)
x1_vals_4 = x1
x1_vals_poly_4 = poly_features_4.transform(x1_vals_4)
y1_vals_4 = reg1_1_4.predict(x1_vals_poly_4)
plt.suptitle('DATA 1 : Degree 4')
plt.ylabel('Output')
plt.xlabel('Input')
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x1, y1)
plt.plot(x1_vals_4_show, y1_vals_4_show, color="r")
plt.show()

# %%
print(f" intercept : {reg1_1_4.intercept_} \n coefficient : {reg1_1_4.coef_} \n MSE : {metrics.mean_squared_error(y1, y1_vals_4)} \n R2 Score : {r2_score(y1, y1_vals_4)}")
# Out:
#  intercept : [3.58991016]
#  coefficient : [[25.85120202 31.87331493 12.27001634  1.40836351]]
#  MSE : 1.2712131499088722e-24
#  R2 Score : 1.0

# %%
# DEGREE = 16

poly_features_16 = PolynomialFeatures(degree=16, include_bias=False)
x1_poly_16 = poly_features_16.fit_transform(x1)
reg1_1_16 = LinearRegression()
reg1_1_16.fit(x1_poly_16, y1)
x1_vals_16_show = np.linspace(-5,5,100).reshape(-1,1)
x1_vals_poly_16_show = poly_features_16.transform(x1_vals_16_show)
y1_vals_16_show = reg1_1_16.predict(x1_vals_poly_16_show)
x1_vals_16 = x1
x1_vals_poly_16 = poly_features_16.transform(x1_vals_16)
y1_vals_16 = reg1_1_16.predict(x1_vals_poly_16)
plt.suptitle('DATA 1 : Degree 16')
plt.ylabel('Output')
plt.xlabel('Input')
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x1, y1)
plt.plot(x1_vals_16_show, y1_vals_16_show, color="r")
plt.show()

# %%
print(f" intercept : {reg1_1_16.intercept_} \n coefficient : {reg1_1_16.coef_} \n MSE : {metrics.mean_squared_error(y1, y1_vals_16)} \n R2 Score : {r2_score(y1, y1_vals_16)}")
# Out:
#  intercept : [5.00349683]
#  coefficient : [[ 0.00369035 -0.00491833  0.00680425 -0.00936883  0.01282869 -0.01739883
#    0.02321525 -0.03012484  0.03724755 -0.04221328  0.04025241 -0.02451463
#   -0.00766526  0.03352207  0.01634977  0.00197614]]
#  MSE : 1.7328808411505004e-16
#  R2 Score : 1.0

# %%
### DATA 2

# %%
### DATA 2     25

# %%
# dataset2 :
x2 = np.random.rand(25,1) *10 -5
y2 = 2 * x2 + 5
y2 = y2 + np.random.normal(scale=1, size=y2.shape)
plt.plot(x2, y2, 'bo')

# %%
# DEGREE = 1

poly_features = PolynomialFeatures(degree=1, include_bias=False)
x2_poly = poly_features.fit_transform(x2)
reg2_1 = LinearRegression()
reg2_1.fit(x2_poly, y2)
# x2_vals = np.linspace(-5,5,5).reshape(-1,1)
x2_vals = x2
x2_vals_poly = poly_features.transform(x2_vals)
y2_vals = reg2_1.predict(x2_vals_poly)
plt.suptitle('DATA 2 : Degree 1')
plt.ylabel('Output')
plt.xlabel('Input')
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x2, y2)
plt.plot(x2_vals, y2_vals, color="r")
plt.show()

# %%
print(f" intercept : {reg2_1.intercept_} \n coefficient : {reg2_1.coef_} \n MSE : {metrics.mean_squared_error(y2, y2_vals)} \n R2 Score : {r2_score(y2, y2_vals)}")
# Out:
#  intercept : [5.06517251]
#  coefficient : [[2.03867111]]
#  MSE : 1.0808076327546519
#  R2 Score : 0.9722726332794523

# %%
## DEGREE = 4

poly_features_4 = PolynomialFeatures(degree=4, include_bias=False)
x2_poly_4 = poly_features_4.fit_transform(x2)
reg2_1_4 = LinearRegression()
reg2_1_4.fit(x2_poly_4, y2)
x2_vals_4_show = np.linspace(-5,5,500).reshape(-1,1)
x2_vals_poly_4_show = poly_features_4.transform(x2_vals_4_show)
y2_vals_4_show = reg2_1_4.predict(x2_vals_poly_4_show)
x2_vals_4 = x2
x2_vals_poly_4 = poly_features_4.transform(x2_vals_4)
y2_vals_4 = reg2_1_4.predict(x2_vals_poly_4)
plt.suptitle('DATA 2 : Degree 4')
plt.ylabel('Output')
plt.xlabel('Input')
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x2, y2)
plt.plot(x2_vals_4_show, y2_vals_4_show, color="r")
plt.show()

# %%
print(f" intercept : {reg2_1_4.intercept_} \n coefficient : {reg2_1_4.coef_} \n MSE : {metrics.mean_squared_error(y2, y2_vals_4)} \n R2 Score : {r2_score(y2, y2_vals_4)}")
# Out:
#  intercept : [5.72221155]
#  coefficient : [[ 1.68558533e+00 -8.64027263e-02  2.12902036e-02  1.39930623e-03]]
#  MSE : 0.7147948444409371
#  R2 Score : 0.9816624363289728

# %%
# DEGREE = 16

poly_features_16 = PolynomialFeatures(degree=16, include_bias=False)
x2_poly_16 = poly_features_16.fit_transform(x2)
reg2_1_16 = LinearRegression()
reg2_1_16.fit(x2_poly_16, y2)
x2_vals_16_show = np.linspace(-5,5,100).reshape(-1,1)
x2_vals_poly_16_show = poly_features_16.transform(x2_vals_16_show)
y2_vals_16_show = reg2_1_16.predict(x2_vals_poly_16_show)
x2_vals_16 = x2
x2_vals_poly_16 = poly_features_16.transform(x2_vals_16)
y2_vals_16 = reg2_1_16.predict(x2_vals_poly_16)
plt.suptitle('DATA 2 : Degree 16')
plt.ylabel('Output')
plt.xlabel('Input')
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x2, y2)
plt.plot(x2_vals_16_show, y2_vals_16_show, color="r")
plt.show()

# %%
print(f" intercept : {reg2_1_16.intercept_} \n coefficient : {reg2_1_16.coef_} \n MSE : {metrics.mean_squared_error(y2, y2_vals_16)} \n R2 Score : {r2_score(y2, y2_vals_16)}")
# Out:
#  intercept : [6.17301887]
#  coefficient : [[-3.81442243e+00 -1.15297615e+01  6.87087281e+00  1.14393102e+01
#   -2.97245098e+00 -4.27342658e+00  6.15601045e-01  7.83757379e-01
#   -6.71772341e-02 -7.74966720e-02  3.97744419e-03  4.21245687e-03
#   -1.20989844e-04 -1.18529486e-04  1.48171120e-06  1.34959229e-06]]
#  MSE : 0.2730535001404202
#  R2 Score : 0.9929950027153063

# %%
### DATA 3

# %% [markdown]
# DATA 3  : 100

# %%
# dataset3 :
x3 = np.random.rand(100,1) *10 -5
y3 = 2 * x3 + 5
y3 = y3 + np.random.normal(scale=1, size=y3.shape)
plt.plot(x3, y3, 'bo')

# %%
# DEGREE = 1

poly_features = PolynomialFeatures(degree=1, include_bias=False)
x3_poly = poly_features.fit_transform(x3)
reg3_1 = LinearRegression()
reg3_1.fit(x3_poly, y3)
# x3_vals = np.linspace(-5,5,100).reshape(-1,1)
x3_vals = x3
x3_vals_poly = poly_features.transform(x3_vals)
y3_vals = reg3_1.predict(x3_vals_poly)
plt.suptitle('DATA 3 : Degree 1')
plt.ylabel('Output')
plt.xlabel('Input')
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x3, y3)
plt.plot(x3_vals, y3_vals, color="r")
plt.show()

# %%
print(f" intercept : {reg3_1.intercept_} \n coefficient : {reg3_1.coef_} \n MSE : {metrics.mean_squared_error(y3, y3_vals)} \n R2 Score : {r2_score(y3, y3_vals)}")
# Out:
#  intercept : [5.05416678]
#  coefficient : [[2.02511987]]
#  MSE : 0.8919460381268316
#  R2 Score : 0.9718189760223828

# %%
## DEGREE = 4

poly_features_4 = PolynomialFeatures(degree=4, include_bias=False)
x3_poly_4 = poly_features_4.fit_transform(x3)
reg3_1_4 = LinearRegression()
reg3_1_4.fit(x3_poly_4, y3)
x3_vals_4_show = np.linspace(-5,5,500).reshape(-1,1)
x3_vals_poly_4_show = poly_features_4.transform(x3_vals_4_show)
y3_vals_4_show = reg3_1_4.predict(x3_vals_poly_4_show)
x3_vals_4 = x3
x3_vals_poly_4 = poly_features_4.transform(x3_vals_4)
y3_vals_4 = reg3_1_4.predict(x3_vals_poly_4)
plt.suptitle('DATA 3 : Degree 4')
plt.ylabel('Output')
plt.xlabel('Input')
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x2, y2)
plt.plot(x3_vals_4_show, y3_vals_4_show, color="r")
plt.show()

# %%
print(f" intercept : {reg3_1_4.intercept_} \n coefficient : {reg3_1_4.coef_} \n MSE : {metrics.mean_squared_error(y3, y3_vals_4)} \n R2 Score : {r2_score(y3, y3_vals_4)}")
# Out:
#  intercept : [5.27441042]
#  coefficient : [[ 2.07682804e+00 -3.94496190e-02 -3.40097178e-03  6.61878583e-04]]
#  MSE : 0.8554189217071175
#  R2 Score : 0.9729730498112176

# %%
# DEGREE = 16

poly_features_16 = PolynomialFeatures(degree=16, include_bias=False)
x3_poly_16 = poly_features_16.fit_transform(x3)
reg3_1_16 = LinearRegression()
reg3_1_16.fit(x3_poly_16, y3)
x3_vals_16_show = np.linspace(-5,5,100).reshape(-1,1)
x3_vals_poly_16_show = poly_features_16.transform(x3_vals_16_show)
y3_vals_16_show = reg3_1_16.predict(x3_vals_poly_16_show)
x3_vals_16 = x3
x3_vals_poly_16 = poly_features_16.transform(x3_vals_16)
y3_vals_16 = reg3_1_16.predict(x3_vals_poly_16)
plt.suptitle('DATA 3 : Degree 16')
plt.ylabel('Output')
plt.xlabel('Input')
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x3, y3)
plt.plot(x3_vals_16_show, y3_vals_16_show, color="r")
plt.show()

# %%
print(f" intercept : {reg3_1_16.intercept_} \n coefficient : {reg3_1_16.coef_} \n MSE : {metrics.mean_squared_error(y3, y3_vals_16)} \n R2 Score : {r2_score(y3, y3_vals_16)}")
# Out:
#  intercept : [5.09191751]
#  coefficient : [[ 1.99657572e+00  4.57603728e-01  4.34265253e-01 -2.32657734e-01
#   -2.51955904e-01  4.60586659e-02  5.88856897e-02 -4.76661347e-03
#   -6.80274974e-03  2.56676880e-04  4.09234827e-04 -5.58533472e-06
#   -1.22775756e-05 -3.41972654e-08  1.45085522e-07  2.25133063e-09]]
#  MSE : 0.7805792893460374
#  R2 Score : 0.9753376070645609

# %%
### DATA 4

# %%
### DATA 4 : 1000

# %%
# dataset4 :
x4 = np.random.rand(1000,1) *10 -5
y4 = 2 * x4 + 5
y4 = y4 + np.random.normal(scale=1, size=y4.shape)
plt.plot(x4, y4, 'bo')

# %%
# DEGREE = 1

poly_features = PolynomialFeatures(degree=1, include_bias=False)
x4_poly = poly_features.fit_transform(x4)
reg4_1 = LinearRegression()
reg4_1.fit(x4_poly, y4)
# x4_vals = np.linspace(-5,5,1000).reshape(-1,1)
x4_vals = x4
x4_vals_poly = poly_features.transform(x4_vals)
y4_vals = reg4_1.predict(x4_vals_poly)
plt.suptitle('DATA 4 : Degree 1')
plt.ylabel('Output')
plt.xlabel('Input')
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x4, y4)
plt.plot(x4_vals, y4_vals, color="r")
plt.show()

# %%
print(f" intercept : {reg4_1.intercept_} \n coefficient : {reg4_1.coef_} \n MSE : {metrics.mean_squared_error(y4, y4_vals)} \n R2 Score : {r2_score(y4, y4_vals)}")
# Out:
#  intercept : [4.93886458]
#  coefficient : [[1.99942778]]
#  MSE : 1.0477750680470628
#  R2 Score : 0.9696129181035397

# %%
## DEGREE = 4

poly_features_4 = PolynomialFeatures(degree=4, include_bias=False)
x4_poly_4 = poly_features_4.fit_transform(x4)
reg4_1_4 = LinearRegression()
reg4_1_4.fit(x4_poly_4, y4)
x4_vals_4_show = np.linspace(-5,5,500).reshape(-1,1)
x4_vals_poly_4_show = poly_features_4.transform(x4_vals_4_show)
y4_vals_4_show = reg4_1_4.predict(x4_vals_poly_4_show)
x4_vals_4 = x4
x4_vals_poly_4 = poly_features_4.transform(x4_vals_4)
y4_vals_4 = reg4_1_4.predict(x4_vals_poly_4)
plt.suptitle('DATA 4 : Degree 4')
plt.ylabel('Output')
plt.xlabel('Input')
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x4, y4)
plt.plot(x4_vals_4_show, y4_vals_4_show, color="r")
plt.show()

# %%
print(f" intercept : {reg4_1_4.intercept_} \n coefficient : {reg4_1_4.coef_} \n MSE : {metrics.mean_squared_error(y4, y4_vals_4)} \n R2 Score : {r2_score(y4, y4_vals_4)}")
# Out:
#  intercept : [4.96657921]
#  coefficient : [[ 2.01185600e+00  3.30955095e-03 -9.52540703e-04 -4.57246797e-04]]
#  MSE : 1.0449008725440483
#  R2 Score : 0.9696962741756586

# %%
# DEGREE = 16

poly_features_16 = PolynomialFeatures(degree=16, include_bias=False)
x4_poly_16 = poly_features_16.fit_transform(x4)
reg4_1_16 = LinearRegression()
reg4_1_16.fit(x4_poly_16, y4)
x4_vals_16_show = np.linspace(-5,5,100).reshape(-1,1)
x4_vals_poly_16_show = poly_features_16.transform(x4_vals_16_show)
y4_vals_16_show = reg4_1_16.predict(x4_vals_poly_16_show)
x4_vals_16 = x4
x4_vals_poly_16 = poly_features_16.transform(x4_vals_16)
y4_vals_16 = reg4_1_16.predict(x4_vals_poly_16)
plt.suptitle('DATA 4 : Degree 16')
plt.ylabel('Output')
plt.xlabel('Input')
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x4, y4)
plt.plot(x4_vals_16_show, y4_vals_16_show, color="r")
plt.show()

# %%
print(f" intercept : {reg4_1_16.intercept_} \n coefficient : {reg4_1_16.coef_} \n MSE : {metrics.mean_squared_error(y4, y4_vals_16)} \n R2 Score : {r2_score(y4, y4_vals_16)}")
# Out:
#  intercept : [4.8497178]
#  coefficient : [[ 1.98638722e+00  2.77368926e-01  1.71144368e-01 -1.03177705e-01
#   -8.58643371e-02  1.05659628e-02  1.68504536e-02  5.65475361e-04
#   -1.65473928e-03 -1.84323154e-04  8.61362928e-05  1.37330009e-05
#   -2.26734799e-06 -4.39844879e-07  2.37310644e-08  5.26477048e-09]]
#  MSE : 1.036056971155952
#  R2 Score : 0.9699527608625057

# %%
plt.figure(figsize=(16,16))

# 5

plt.subplot(431)

#plt.suptitle('DATA 1')
plt.ylabel("degree = 1")
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x1, y1)
plt.plot(x1_vals, y1_vals, color="r")

plt.subplot(432)

plt.ylabel("degree = 4")
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x1, y1)
plt.plot(x1_vals_4_show, y1_vals_4_show, color="r")

plt.subplot(433)

plt.ylabel("degree = 16")
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x1, y1)
plt.plot(x1_vals_16_show, y1_vals_16_show, color="r")

# 25

plt.subplot(434)

#plt.suptitle('DATA 2')
plt.ylabel("degree = 1")
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x2, y2)
plt.plot(x2_vals, y2_vals, color="r")

plt.subplot(435)

plt.ylabel("degree = 4")
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x2, y2)
plt.plot(x2_vals_4_show, y2_vals_4_show, color="r")

plt.subplot(436)
plt.ylabel("degree = 16")
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x2, y2)
plt.plot(x2_vals_16_show, y2_vals_16_show, color="r")


# 100

plt.subplot(437)

#plt.suptitle('DATA 3')
plt.ylabel("degree = 1")
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x3, y3)
plt.plot(x3_vals, y3_vals, color="r")

plt.subplot(438)

plt.ylabel("degree = 4")
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x3, y3)
plt.plot(x3_vals_4_show, y3_vals_4_show, color="r")

plt.subplot(439)

plt.ylabel("degree = 16")
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x3, y3)
plt.plot(x3_vals_16_show, y3_vals_16_show, color="r")



# 1000

plt.subplot(4,3,10)

#plt.suptitle('DATA 4')
plt.ylabel("degree = 1")
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x4, y4)
plt.plot(x4_vals, y4_vals, color="r")

plt.subplot(4,3,11)

plt.ylabel("degree = 4")
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x4, y4)
plt.plot(x4_vals_4_show, y4_vals_4_show, color="r")

plt.subplot(4,3,12)

plt.ylabel("degree = 16")
plt.ylim((-20,20))
plt.xlim((-5,5))
plt.scatter(x4, y4)
plt.plot(x4_vals_16_show, y4_vals_16_show, color="r")



plt.show()

# %%
#Accuracy Analysis :
plt.suptitle('Analysis')
plt.ylabel("MSE")
plt.xlabel("Data count \n 1:5 , 2:25 , 3:100 , 4:1000")
plt.ylim((-0.5,2))
plt.xlim((0,5))
plt.scatter(1,metrics.mean_squared_error(y1, y1_vals_16),s=180, color="#9f0000")
plt.scatter(1,metrics.mean_squared_error(y1, y1_vals_4),s=50, color="#54ff9f")
plt.scatter(1,metrics.mean_squared_error(y1, y1_vals),s=20, color="#2e2d88")

plt.scatter(2,metrics.mean_squared_error(y2, y2_vals_16),s=180,color="#9f0000")
plt.scatter(2,metrics.mean_squared_error(y2, y2_vals_4),s=70,color="#54ff9f")
plt.scatter(2,metrics.mean_squared_error(y2, y2_vals),s=20,color="#2e2d88")

plt.scatter(3,metrics.mean_squared_error(y3, y3_vals_16),s=180,color="#9f0000")
plt.scatter(3,metrics.mean_squared_error(y3, y3_vals_4),s=70, color="#54ff9f")
plt.scatter(3,metrics.mean_squared_error(y3, y3_vals),s=20, color="#2e2d88")

plt.scatter(4,metrics.mean_squared_error(y4, y4_vals_16),s=180, color="#9f0000")
plt.scatter(4,metrics.mean_squared_error(y4, y4_vals_4),s=70,color="#54ff9f")
plt.scatter(4,metrics.mean_squared_error(y4, y4_vals),s=20,color="#2e2d88")


plt.legend(["degree = 16" , "degree = 4","degree = 1"])
plt.grid(True)
plt.show()

# %%
MSE_power_1_1 = np.log10(metrics.mean_squared_error(y1, y1_vals))
MSE_power_1_4 = np.log10(metrics.mean_squared_error(y1, y1_vals_4))
MSE_power_1_16 = np.log10(metrics.mean_squared_error(y1, y1_vals_16))

# %%
MSE_power_2_1 = np.log10(metrics.mean_squared_error(y2, y2_vals))
MSE_power_2_4 = np.log10(metrics.mean_squared_error(y2, y2_vals_4))
MSE_power_2_16 = np.log10(metrics.mean_squared_error(y2, y2_vals_16))

# %%
MSE_power_3_1 = np.log10(metrics.mean_squared_error(y3, y3_vals))
MSE_power_3_4 = np.log10(metrics.mean_squared_error(y3, y3_vals_4))
MSE_power_3_16 = np.log10(metrics.mean_squared_error(y3, y3_vals_16))

# %%
MSE_power_4_1 = np.log10(metrics.mean_squared_error(y4, y4_vals))
MSE_power_4_4 = np.log10(metrics.mean_squared_error(y4, y4_vals_4))
MSE_power_4_16 = np.log10(metrics.mean_squared_error(y4, y4_vals_16))

# %%
#Accuracy Analysis BASED ON POWER OF MSEs :
# fig, ax = plt.subplots()
plt.suptitle('Analysis')
plt.ylabel("Power of MSE")
plt.xlabel("Data count \n 1:5 , 2:25 , 3:100 , 4:1000")
plt.ylim((-50,50))
plt.xlim((0,5))
plt.scatter(1,MSE_power_1_16,s=180, color="#9f0000")
plt.scatter(1,MSE_power_1_4,s=50, color="#54ff9f")
plt.scatter(1,MSE_power_1_1,s=20, color="#2e2d88")

plt.scatter(2,MSE_power_2_16,s=180,color="#9f0000")
plt.scatter(2,MSE_power_2_4,s=70,color="#54ff9f")
plt.scatter(2,MSE_power_2_1,s=20,color="#2e2d88")

plt.scatter(3,MSE_power_3_16,s=180,color="#9f0000")
plt.scatter(3,MSE_power_3_4,s=70, color="#54ff9f")
plt.scatter(3,MSE_power_3_1,s=20, color="#2e2d88")

plt.scatter(4,MSE_power_4_16,s=180, color="#9f0000")
plt.scatter(4,MSE_power_4_4,s=70,color="#54ff9f")
plt.scatter(4,MSE_power_4_1,s=20,color="#2e2d88")


plt.legend(["degree = 16" , "degree = 4","degree = 1"])
plt.grid(True)
plt.show()
